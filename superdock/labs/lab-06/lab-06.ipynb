# %% [markdown]
# # Lab 6: Counting & drawing with while-loops.
#
# This lab asks you to solve a series of problems by writing while-loops.
#
# You may either complete this lab individually, or with a partner using pair-programming. If you choose to work with a partner, edit the cell below to enter your names; you only need to submit one lab between the two of you.

# %% [markdown]
# - Partner 1: [name here]
# - Partner 2: [name here]

# %% [markdown]
# ## Problem 1: Countdown.
#
# Write code that counts down from 100 to 0 by 2's, printing each number on its own line. The first few lines and the last line should be as follows:
#
# ```
# 100
# 98
# 96
#
# ...
#
# 0
# ```
#
# Use a count-controlled while-loop like we practiced last class.

# %%
# Write your code inside of this main function:
def main():
    pass
    
main()

# %% [markdown]
# ## Problem 2: Stars
#
# Write code that uses a count-controlled while-loop to print the following text, which consists of 20 rows of stars:
#
# ```
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# ```

# %%
# Write your code inside of this main function:
def main():
    pass

main()

# %% [markdown]
# ## Problem 3: Stripes.
#
# Draw the following picture.
#
# Each stripe (blue or white) is exactly 10 pixels high.
#
# ![image.png](attachment:image.png)
#
# **Suggestion:** Start by drawing just the first three stripes without a loop. Then figure out how to incorporate a while-loop.
#
# Remember, you can look up functions in our [Python reference](https://cs.rhodes.edu/~superdockm/comp141/doc2) as you work!

# %%
from cs1.graphics import *

def main():
    open_canvas(500, 500)
    
main()

# %% [markdown]
# ## Problem 4: Main diagonal.
#
# Draw the following picture, which consists of 10-pixel squares along the main diagonal.
#
# The first square has its upper-left corner at (0, 0).
#
# ![image.png](attachment:image.png)
#
# **Suggestion:** Start by drawing just the first three squares without a loop. Then figure out how to incorporate a while-loop.
#
# Remember, you can look up functions in our [Python reference](https://cs.rhodes.edu/~superdockm/comp141/doc2) as you work!

# %%
from cs1.graphics import *

def main():
    open_canvas(500, 500)
    
main()

# %% [markdown]
# ## Problem 5: Distorted bulls-eye.
#
# Draw the following picture, which consists of red and white filled circles drawn on top of one another.
#
# The outermost circle has radius 250, and each subsequent circle has a radius 10 smaller than the previous one.
#
# ![image.png](attachment:image.png)
#
# Remember, you can look up functions in our [Python reference](https://cs.rhodes.edu/~superdockm/comp141/doc2) as you work!

# %%
from cs1.graphics import *

def main():
    open_canvas(500, 500)
    
main()

# %% [markdown]
# ## Feedback.
#
# Are there any parts of this lab that you're confused about? Are there any parts that you'd like to discuss in class?
#
# If so, create a new Markdown cell below to answer. If not, continue to the next part.

# %% [markdown]
# ## Submit.
#
# Run the cell below to submit your lab. As usual, you may submit as many times as you like before the deadline.
#
# Be sure to click the URL that appears after you submit, to make sure that your notebook is submitted properly.
#
# Remember that labs are graded for completeness; for full credit, I'd like to see a good effort towards solving each problem.

# %%
from cs1.notebooks import *
ok_submit('lab-06.ok')
