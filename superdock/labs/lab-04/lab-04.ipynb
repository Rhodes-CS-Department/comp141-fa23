# %% [markdown]
# # Lab 4: Bulls-eye & functions.
#
# This lab involves drawing bulls-eyes using functions. The main goal is to improve our ability to write functions.
#
# We will complete this lab in pairs, using **pair-programming**. Choose a single computer to work on, and edit the cell below to enter your names:

# %% [markdown]
# - Partner 1: [name here]
# - Partner 2: [name here]

# %% [markdown]
# ## Step 1: Write the `draw_bullseye()` function.
#
# In the block below, write a function `draw_bullseye()` that draws the following bulls-eye:
#
# - You may assume that the canvas is a square, 500 pixels by 500 pixels.
# - The bulls-eye should be centered vertically and horizontally.
# - The rings of the bulls-eye should be made up of circles of radius 10, 20, 30, 40, and 50.
#
# ![image.png](attachment:image.png)
#
# You are given a `main()` function that opens a 500-by-500 canvas and calls `draw_bullseye()`.
#
# You're welcome to copy from our notes from last class's.

# %%
from cs1.graphics import *

# Draw a bullseye, centered vertically and horizontally.
# Returns None (NoneType).
def draw_bullseye():
    # TODO: Write code here. (Delete this comment.)

def main():
    open_canvas(500, 500)
    draw_bullseye()

main()

# %% [markdown]
# ## Step 2: Adding parameters `x` and `y` to `draw_bullseye()`.
#
# Let's make `draw_bullseye()` take parameters `x` and `y`, representing the coordinates of the center of the bullseye. This makes our function more general--instead of always drawing a bulls-eye at the center of the canvas, it will now be able to draw a bulls-eye at any specified location.
#
# You are given a `main()` function that opens a 500-by-500 canvas and calls `draw_bullseye()` with two different sets of coordinates (x, y).
#
# You might start by copy-pasting your function body from step 1 and modifying it to use `x` and `y`.

# %%
from cs1.graphics import *

# Draw a bullseye, centered at (x, y).
# x - x-coordinate of the center of the bulls-eye (int).
# y - y-coordinate of the center of the bulls-eye (int).
# Returns None (NoneType).
def draw_bullseye(x, y):
    # TODO: Write code here. (Delete this comment.)

def main():
    open_canvas(500, 500)
    draw_bullseye(100, 100)
    draw_bullseye(300, 400)

main()

# %% [markdown]
# ## Step 3: Adding parameters `color1` and `color2` to `draw_bullseye()`.
#
# Let's make `draw_bullseye()` take parameters `color1` and `color2`, representing the colors used to draw the bullseye.
#
# You're now responsible for all of the code, not just the function body.
#
# Suggested steps:
#
# - Copy-paste the whole block of code from step 2 into the block below (including the import statement, `draw_bullseye()`, and `main()`).
# - Add parameters `color1` and `color2` to `draw_bullseye()`, and change the body of `draw_bullseye()` accordingly.
# - Adjust the function comment above `draw_bullseye()` to reflect the changes. (Add lines that explain `color1` and `color2`, including their types.)
# - Change the `main()` function to draw two bulls-eyes in different colors, instead of just red and white.

# %%
# Copy your code from Step 2 here and modify it as specified.

# %% [markdown]
# ## Step 4: Taking user input.
#
# Modify your `main()` function so the user can input the (x, y) coordinates of the center of the bullseye, and the colors they want to use for it. This will require four calls to the `input()` function: one for `x`, one for `y`, and two for the colors.
#
# **Note:** The `draw_bullseye()` function should not have any calls to the `input()` function.
#
# Start by copying your code from step 3 into the block below.

# %%
# Copy your code from Step 3 here and modify it as specified.

# %% [markdown]
# ## Step 5: Adding a parameter `radius` to `draw_bullseye()`.
#
# Modify your `draw_bullseye()` function definition to take a fifth argument, the radius of the bullseye. You’ll
# need to do some math to figure out what the radii of the nested circles should be changed to.
#
# Then adjust your `main()` function to draw two bulls-eyes, both with radius 100.
#
# **Note:** You don't need to ask the user to input a radius--just use a radius 100 for both bullseyes.

# %%
# Copy your code from Step 4 here and modify it as specified.

# %% [markdown]
# ## Step 6: Drawing Mickey Mouse ears.
#
# Modify your `main()` function so three bullseyes are drawn after the user inputs the four variables, as shown below:
#
# - The center bullseye should be drawn as in step 4 (based off the inputs the user supplies, using a radius of 50).
# - The second and third bullseyes should be smaller, and offset slightly, as shown below.
#
# **Note:** The `draw_bullseye()` function should not change in this step--it should still draw just one bullseye.
#
# ![mickeyMouse.png](attachment:mickeyMouse.png)

# %%
# Copy your code from Step 5 here and modify it as specified.

# %% [markdown]
# ## Feedback.
#
# Are there any parts of this lab that you're confused about? Are there any parts that you'd like to discuss in class?
#
# If so, create a new Markdown cell below to answer. If not, continue to the next part.

# %% [markdown]
# ## Submit.
#
# Run the cell below to submit your lab. As usual, you may submit as many times as you like before the deadline.
#
# Be sure to click the URL that appears after you submit, to make sure that your notebook is submitted properly.
#
# Remember that labs are graded for completeness; for full credit, I'd like to see *at least an effort* towards each of the required features of the program.

# %%
# Run this cell to log in to okpy.org, and submit your lab.
from cs1.notebooks import *
ok_submit('lab-04.ok')

# %% [markdown]
# ## Additional challenges.
#
# These are optional and not required for full credit. Here are some ideas for changes you can make to your current program:
#
# 1. Ask the user to also input a radius for the center bulls-eye of the Mickey Mouse ears, and scale the other two bulls-eyes accordingly.
#
# 2. Write a function called `draw_square(x, y, side)` that takes as arguments the (x, y) coordinates of the center of a square and the length of a side, and draws an appropriately-sized and positioned square on the canvas.
#
# 3. Write a function called `draw_nested_squares` that acts just like `draw_bullseye`, but the effect is a set of nested squares, rather than nested circles. This is more mathematically challenging. You can use `draw_filled_rect` for this.

# %%
# Code for challenge questions.
